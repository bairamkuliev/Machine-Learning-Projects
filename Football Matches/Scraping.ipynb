# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
standings_url = "https://fbref.com/en/comps/26/Super-Lig-Stats"

# %%
data = requests.get(standings_url)

# %%
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]
links = standings_table.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if '/squads/' in l]

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
data = requests.get(team_urls[0])

# %%
matches = pd.read_html(data.text, match="Scores & Fixtures")
matches[0].head()
# Out:
#          Date   Time       Comp                   Round  Day    Venue Result  \
# 0  2021-08-05  20:30    Conf Lg  Third qualifying round  Thu  Neutral      D
# 1  2021-08-12  18:00    Conf Lg  Third qualifying round  Thu  Neutral      D
# 2  2021-08-16  19:15  Süper Lig             Matchweek 1  Mon     Away      W
# 3  2021-08-19  20:30    Conf Lg          Play-off round  Thu     Home      L
# 4  2021-08-23  19:15  Süper Lig             Matchweek 2  Mon     Home      W
#
#       GF     GA       Opponent  Poss  Attendance        Captain Formation  \
# 0      3      3       no Molde   NaN     12415.0  Uğurcan Çakır     4-3-3
# 1  1 (4)  1 (3)       no Molde   NaN      2792.0  Uğurcan Çakır     4-3-3
# 2      5      1  Yeni Mal'spor  60.0         NaN  Uğurcan Çakır     4-3-3
# 3      1      2        it Roma   NaN     12870.0  Uğurcan Çakır     4-3-3
# 4      2      1      Sivasspor  53.0         NaN  Uğurcan Çakır   4-2-3-1
#
#               Referee  Match Report  \
# 0         Harm Osmers  Match Report
# 1     Fábio Veríssimo  Match Report
# 2    Atilla Karaoğlan  Match Report
# 3           Matej Jug  Match Report
# 4  Abdulkadir Bitigen  Match Report
#
#                                                Notes
# 0                                         Leg 1 of 2
# 1  Leg 2 of 2; Trabzonspor won; Trabzonspor won o...
# 2                                                NaN
# 3                                         Leg 1 of 2
# 4                                                NaN

# %%
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l]

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
shooting = pd.read_html(data.text, match="Shooting")[0]

# %%
shooting.head()
# Out:
#   For Trabzonspor                                                          \
#              Date   Time       Comp                   Round  Day    Venue
# 0      2021-08-05  20:30    Conf Lg  Third qualifying round  Thu  Neutral
# 1      2021-08-12  18:00    Conf Lg  Third qualifying round  Thu  Neutral
# 2      2021-08-16  19:15  Süper Lig             Matchweek 1  Mon     Away
# 3      2021-08-19  20:30    Conf Lg          Play-off round  Thu     Home
# 4      2021-08-23  19:15  Süper Lig             Matchweek 2  Mon     Home
#
#                                       Standard                               \
#   Result     GF     GA       Opponent      Gls    Sh  SoT  SoT%  G/Sh G/SoT
# 0      D      3      3       no Molde        3   NaN  NaN   NaN   NaN   NaN
# 1      D  1 (4)  1 (3)       no Molde        1   NaN  NaN   NaN   NaN   NaN
# 2      W      5      1  Yeni Mal'spor        5  14.0  8.0  57.1  0.29  0.50
# 3      L      1      2        it Roma        1   NaN  NaN   NaN   NaN   NaN
# 4      W      2      1      Sivasspor        2  14.0  6.0  42.9  0.07  0.17
#
#                 Unnamed: 19_level_0
#   Dist PK PKatt        Match Report
# 0  NaN  0     1        Match Report
# 1  NaN  0     0        Match Report
# 2  NaN  1     1        Match Report
# 3  NaN  0     0        Match Report
# 4  NaN  1     1        Match Report

# %%
shooting.columns = shooting.columns.droplevel()

# %%
shooting.head()
# Out:
#          Date   Time       Comp                   Round  Day    Venue Result  \
# 0  2021-08-05  20:30    Conf Lg  Third qualifying round  Thu  Neutral      D
# 1  2021-08-12  18:00    Conf Lg  Third qualifying round  Thu  Neutral      D
# 2  2021-08-16  19:15  Süper Lig             Matchweek 1  Mon     Away      W
# 3  2021-08-19  20:30    Conf Lg          Play-off round  Thu     Home      L
# 4  2021-08-23  19:15  Süper Lig             Matchweek 2  Mon     Home      W
#
#       GF     GA       Opponent  Gls    Sh  SoT  SoT%  G/Sh  G/SoT  Dist  PK  \
# 0      3      3       no Molde    3   NaN  NaN   NaN   NaN    NaN   NaN   0
# 1  1 (4)  1 (3)       no Molde    1   NaN  NaN   NaN   NaN    NaN   NaN   0
# 2      5      1  Yeni Mal'spor    5  14.0  8.0  57.1  0.29   0.50   NaN   1
# 3      1      2        it Roma    1   NaN  NaN   NaN   NaN    NaN   NaN   0
# 4      2      1      Sivasspor    2  14.0  6.0  42.9  0.07   0.17   NaN   1
#
#    PKatt  Match Report
# 0      1  Match Report
# 1      0  Match Report
# 2      1  Match Report
# 3      0  Match Report
# 4      1  Match Report

# %%
team_data = matches[0].merge(shooting[["Date", "Sh", "SoT", "Dist", "PK", "PKatt"]], on="Date")

# %%
team_data
# Out:
#           Date   Time       Comp                   Round  Day    Venue Result  \
# 0   2021-08-05  20:30    Conf Lg  Third qualifying round  Thu  Neutral      D
# 1   2021-08-12  18:00    Conf Lg  Third qualifying round  Thu  Neutral      D
# 2   2021-08-16  19:15  Süper Lig             Matchweek 1  Mon     Away      W
# 3   2021-08-19  20:30    Conf Lg          Play-off round  Thu     Home      L
# 4   2021-08-23  19:15  Süper Lig             Matchweek 2  Mon     Home      W
# 5   2021-08-26  19:00    Conf Lg          Play-off round  Thu     Away      L
# 6   2021-08-29  21:45  Süper Lig             Matchweek 3  Sun     Away      W
# 7   2021-09-12  20:00  Süper Lig             Matchweek 4  Sun     Home      D
# 8   2021-09-18  16:00  Süper Lig             Matchweek 5  Sat     Away      W
# 9   2021-09-23  17:00  Süper Lig             Matchweek 6  Thu     Away      D
# 10  2021-09-27  20:00  Süper Lig             Matchweek 7  Mon     Home      D
# 11  2021-10-02  16:00  Süper Lig             Matchweek 8  Sat     Away      W
# 12  2021-10-17  19:00  Süper Lig             Matchweek 9  Sun     Home      W
# 13  2021-10-23  19:00  Süper Lig            Matchweek 10  Sat     Away      W
# 14  2021-10-29  20:00  Süper Lig            Matchweek 11  Fri     Home      W
# 15  2021-11-06  19:00  Süper Lig            Matchweek 12  Sat     Away      W
# 16  2021-11-22  20:00  Süper Lig            Matchweek 13  Mon     Home      W
# 17  2021-11-28  16:00  Süper Lig            Matchweek 14  Sun     Away      W
# 18  2021-12-04  16:00  Süper Lig            Matchweek 15  Sat     Home      W
# 19  2021-12-11  19:00  Süper Lig            Matchweek 16  Sat     Away      L
# 27          Zorbay Küçük  Match Report
# 28         Mete Kalkavan  Match Report
# 29      Halil Umut Meler  Match Report
# 30         Erkan Özdamar  Match Report
# 31          Zorbay Küçük  Match Report
# 32          Ali Şansalan  Match Report
# 33      Volkan Bayarslan  Match Report
# 34          Zorbay Küçük  Match Report
# 35         Erkan Özdamar  Match Report
# 36      Halil Umut Meler  Match Report
# 37    Yaşar Kemal Uğurlu  Match Report
# 38      Atilla Karaoğlan  Match Report
# 39      Volkan Bayarslan  Match Report
# 40          Kadir Sağlam  Match Report
# 41      Atilla Karaoğlan  Match Report
#
#                                                 Notes    Sh   SoT  Dist  PK  \
# 0                                          Leg 1 of 2   NaN   NaN   NaN   0
# 1   Leg 2 of 2; Trabzonspor won; Trabzonspor won o...   NaN   NaN   NaN   0
# 2                                                 NaN  14.0   8.0   NaN   1
# 3                                          Leg 1 of 2   NaN   NaN   NaN   0
# 4                                                 NaN  14.0   6.0   NaN   1
# 5                                Leg 2 of 2; Roma won   NaN   NaN   NaN   0
# 6                                                 NaN  13.0   5.0   NaN   0
# 7                                                 NaN  19.0   6.0   NaN   0
# 8                                                 NaN  12.0   9.0   NaN   0
# 9                                                 NaN  14.0   5.0   NaN   0
# 10                                                NaN  19.0   7.0   NaN   0
# 11                                                NaN  16.0   6.0   NaN   1
# 12                                                NaN  20.0   7.0   NaN   1
# 13                                                NaN   6.0   1.0   NaN   0
# 14                                                NaN  12.0   4.0   NaN   1
# 15                                                NaN   8.0   4.0   NaN   0
# 16                                                NaN  11.0   5.0   NaN   0
# 17                                                NaN   9.0   2.0   NaN   1
# 18                                                NaN   5.0   3.0   NaN   0
# 19                                                NaN  12.0   5.0   NaN   0
# 20                                                NaN  17.0   9.0   NaN   0
# 21                                                NaN  15.0   5.0   NaN   0
# 22                                                NaN  11.0   4.0   NaN   0
# 23                                                NaN  24.0   7.0   NaN   0
# 24                                                NaN  10.0   3.0   NaN   0
# 25                                                NaN  23.0   9.0   NaN   0
# 26                                                NaN  19.0   5.0   NaN   0
# 27                                                NaN   7.0   4.0   NaN   0
# 28                                                NaN  15.0   6.0   NaN   0
# 29                                                NaN  17.0   6.0   NaN   0
# 30                                                NaN  22.0  10.0   NaN   1
# 31                                                NaN  17.0   3.0   NaN   0
# 32                                                NaN  16.0  10.0   NaN   0
# 33                                                NaN  10.0   3.0   NaN   0
# 34                                                NaN   8.0   2.0   NaN   0
# 35                                                NaN  19.0   5.0   NaN   0
# 36                                                NaN  30.0   6.0   NaN   0
# 37                                                NaN  11.0   6.0   NaN   1
# 38                                                NaN   9.0   5.0   NaN   0
# 39                                                NaN  15.0   6.0   NaN   0
# 40                                                NaN  16.0   3.0   NaN   1
# 41                                                NaN  14.0   6.0   NaN   0
#
#     PKatt
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1
# 5       0
# 6       0
# 7       0
# 8       0
# 9       0
# 10      0
# 11      1
# 12      1
# 13      0
# 14      1
# 15      0
# 16      0
# 17      1
# 18      0
# 19      0
# 20      0
# 21      0
# 22      0
# 23      0
# 24      0
# 25      1
# 26      0
# 27      0
# 28      0
# 29      0
# 30      1
# 31      0
# 32      0
# 33      0
# 34      0
# 35      0
# 36      0
# 37      1
# 38      0
# 39      1
# 40      1
# 41      0
#
# [42 rows x 22 columns]

# %%
shooting.shape
# Out:
# (43, 20)

# %%
years = list(range(2022, 2020, -1))
all_matches = []

# %%
standings_url = "https://fbref.com/en/comps/26/Super-Lig-Stats"

# %%
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
        team_data = team_data[team_data["Comp"] == "Süper Lig"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(1)

# %%
len(all_matches)
# Out:
# 41

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df
# Out:
#           date   time       comp         round  day venue result gf ga  \
# 2   2021-08-16  19:15  Süper Lig   Matchweek 1  Mon  Away      W  5  1
# 4   2021-08-23  19:15  Süper Lig   Matchweek 2  Mon  Home      W  2  1
# 6   2021-08-29  21:45  Süper Lig   Matchweek 3  Sun  Away      W  1  0
# 7   2021-09-12  20:00  Süper Lig   Matchweek 4  Sun  Home      D  2  2
# 8   2021-09-18  16:00  Süper Lig   Matchweek 5  Sat  Away      W  1  0
# ..         ...    ...        ...           ...  ...   ...    ... .. ..
# 35  2021-04-28  16:00  Süper Lig  Matchweek 38  Wed  Away      L  3  6
# 36  2021-05-02  16:00  Süper Lig  Matchweek 39  Sun  Home      L  0  1
# 37  2021-05-08  20:30  Süper Lig  Matchweek 40  Sat  Away      L  0  1
# 38  2021-05-11  20:30  Süper Lig  Matchweek 41  Tue  Home      L  1  4
# 39  2021-05-15  18:00  Süper Lig  Matchweek 42  Sat  Away      L  1  5
#
#             opponent  ...  notes    sh  sot dist pk pkatt season         team  \
# 2      Yeni Mal'spor  ...    NaN  14.0  8.0  NaN  1     1   2022  Trabzonspor
# 4          Sivasspor  ...    NaN  14.0  6.0  NaN  1     1   2022  Trabzonspor
# 6        Giresunspor  ...    NaN  13.0  5.0  NaN  0     0   2022  Trabzonspor
# 7        Galatasaray  ...    NaN  19.0  6.0  NaN  0     0   2022  Trabzonspor
# 8          Kasımpaşa  ...    NaN  12.0  9.0  NaN  0     0   2022  Trabzonspor
# ..               ...  ...    ...   ...  ...  ... ..   ...    ...          ...
# 35       Kayserispor  ...    NaN  16.0  7.0  NaN  0     0   2021  Denizlispor
# 36          Rizespor  ...    NaN   8.0  1.0  NaN  0     0   2021  Denizlispor
# 37         Hatayspor  ...    NaN  11.0  2.0  NaN  0     1   2021  Denizlispor
# 38       Galatasaray  ...    NaN   7.0  3.0  NaN  0     0   2021  Denizlispor
# 39  Fatih Karagümrük  ...    NaN   8.0  3.0  NaN  0     0   2021  Denizlispor
#
#     xg  xga
# 2  NaN  NaN
# 4  NaN  NaN
# 6  NaN  NaN
# 7  NaN  NaN
# 8  NaN  NaN
# ..  ..  ...
# 35 NaN  NaN
# 36 NaN  NaN
# 37 NaN  NaN
# 38 NaN  NaN
# 39 NaN  NaN
#
# [1600 rows x 26 columns]

# %%
match_df.to_csv("matches.csv")
